# %% [markdown]
# # 1. Introduction

# %%
import covid19model as c19
import numpy as np
import random as rm
import matplotlib
from matplotlib import pyplot as plt

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
len(c19.cases_per_day_uk)
# Out:
# 40

# %%
country = 'it'
Im, Rm, Id, Rd = c19.run_SIR_model(step_number = 90,time_step= 1.0, 
                                   country = country,
                                   offset = 3,
                                   vital_dynamics = False)
# Out:
# Preconditioned lambda = 0.09380061220271273[1/day]
# Preconditioned gamma = 0.03198872261401686[1/day]
# Initial Error = 2.969259863912346e-09[1/day]
# Best Fit lambda = 0.019564445737284622[1/day]
# Best Fit gamma = 0.020257774052275048[1/day]
# Final Error = 2.583459789146861e-09[1/day]

# %%
c19.plot_results(Im, Rm, Id, Rd, country)

# %%
c19.covid19_gauss(country = country, offset = 0)

# %%
np.arange('2020-02-27', '2020-04-07', dtype='datetime64[D]')
# Out:
# array(['2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01',
#        '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#        '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#        '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13',
#        '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17',
#        '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21',
#        '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25',
#        '2020-03-26', '2020-03-27', '2020-03-28', '2020-03-29',
#        '2020-03-30', '2020-03-31', '2020-04-01', '2020-04-02',
#        '2020-04-03', '2020-04-04', '2020-04-05', '2020-04-06'],
#       dtype='datetime64[D]')

# %%
np.round(2.9)
# Out:
# 3.0
