# %% [markdown]
# # 1. Introduction

# %%
import covid19model as c19
import numpy as np
import random as rm
import matplotlib
from matplotlib import pyplot as plt

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
len(c19.cases_per_day_uk)
# Out:
# 65

# %%
country = 'uk'
Im, Rm, Id, Rd = c19.run_SIR_model(step_number = 90,time_step= 1.0, 
                                   country = country,
                                   offset = 3,
                                   vital_dynamics = True)
# Out:
# Preconditioned lambda = 0.148876742545949[1/day]
# Preconditioned gamma = 0.013114784576295205[1/day]
# Preconditioned mu = 0.016164535085952468[1/day]
# Initial Error = 4.772861540849561e-07[1/day]
# Negative lambda, use preconditioned value.
# Negative gamma, use preconditioned value.
# Negative mu, use preconditioned value.
# Final Error = 4.772861540849561e-07[1/day]

# %%
c19.plot_results(Im, Rm, Id, Rd, country)

# %%
c19.covid19_gauss(country = country, offset = 0)
