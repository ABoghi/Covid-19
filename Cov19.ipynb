# %% [markdown]
# # 1. Introduction

# %%
import covid19model as c19
import numpy as np
import random as rm
import matplotlib
from matplotlib import pyplot as plt

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
len(c19.cases_per_day_uk)
# Out:
# 49

# %%
country = 'uk'
Im, Rm, Id, Rd = c19.run_SIR_model(step_number = 90,time_step= 1.0, 
                                   country = country,
                                   offset = 3,
                                   vital_dynamics = False)
# Out:
# Preconditioned lambda = 0.12816769787185422[1/day]
# Preconditioned gamma = 0.014017477257005194[1/day]
# Initial Error = 1.5105859027149331e-09[1/day]
# Best Fit lambda = 0.029468796796737053[1/day]
# Best Fit gamma = 0.005917348267648827[1/day]
# Final Error = 8.572427476548943e-10[1/day]

# %%
c19.plot_results(Im, Rm, Id, Rd, country)

# %%
c19.covid19_gauss(country = country, offset = 0)

# %%
c19.correlations(country = country)
# Out:
# Preconditioned lambda = 0.15443759285558997[1/day]
# Preconditioned gamma = 0.013159264363719161[1/day]
# Initial Error = 1.928132701823221e-09[1/day]
# Best Fit lambda = 0.029469362478140075[1/day]
# Best Fit gamma = 0.005917349522597698[1/day]
# Final Error = 8.572279723398615e-10[1/day]
