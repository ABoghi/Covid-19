# %% [markdown]
# # 1. Introduction

# %%
import covid19model as c19
import numpy as np
import random as rm
import matplotlib
from matplotlib import pyplot as plt

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
len(c19.cases_per_day_uk)
# Out:
# 37

# %%
Im, Rm, Id, Rd = c19.run_SIR_model(step_number = 90,time_step= 1.0, 
                                   country = 'it',
                                   offset = 0,
                                   vital_dynamics = True)
# Out:
# Preconditioned lambda = 0.1655025729039398[1/day]
# Preconditioned gamma = 0.08229404742479518[1/day]
# Preconditioned mu = 0.05430969380554342[1/day]
# Initial Error = 2.051332149778969e-09[1/day]
# Negative lambda, use preconditioned value.
# Negative gamma, use preconditioned value.
# Negative mu, use preconditioned value.
# Final Error = 2.051332149778969e-09[1/day]

# %%
c19.plot_results(Im, Rm, Id, Rd)

# %%
import datetime as dt

# %%
dt.datetime(2014, 1, 1)
# Out:
# datetime.datetime(2014, 1, 1, 0, 0)

# %%
a = dt.datetime.now()

a = int(a.strftime('%Y%m%d'))
a
# Out:
# 20200404

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
#    (b + c + d + e) = 0.0
#    (c + 2*d + 3 * e) = 0.0
#    (c/2 + 4*d/2 + 9*e/2) = 1
#    (c/6 + 8*d/6 + 27*e/6) = 0
A = np.array([[1, 1, 1, 1], [0, 1, 2, 3], [0, 1/2, 2, 9/2], [0, 1/6, 8/6, 27/6]])
b = np.array([0, 0, 1, 0])

# %%
np.linalg.inv(A)
# Out:
# array([[ 1.        , -1.83333333,  2.        , -1.        ],
#        [ 0.        ,  3.        , -5.        ,  3.        ],
#        [ 0.        , -1.5       ,  4.        , -3.        ],
#        [ 0.        ,  0.33333333, -1.        ,  1.        ]])

# %%
b[0:]
# Out:
# array([0, 0, 1, 0])

# %%
np.array([[0,0],[0,0]])
# Out:
# array([[0, 0],
#        [0, 0]])

# %%
A = np.array([[1.0, 2.0],[3.0, 4.0]])
A[0][1]
# Out:
# 2.0

# %%
A
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
A.T
# Out:
# array([[1., 3.],
#        [2., 4.]])

# %%
np.matmul(A.T,A)
# Out:
# array([[10., 14.],
#        [14., 20.]])

# %%
b = np.array([1, 0])

# %%
np.matmul(A,b)
# Out:
# array([1., 3.])
